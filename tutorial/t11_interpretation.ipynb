# %% [markdown]
# # Tutorial 11: Interpretation
# ___
#
# In this tutorial we introduce the interpretation module, which provides various mechanisms for users to visualize / interpret what a neural network is seeing / focusing on within an input in order to make its decision. Since it will demonstrate bash commands which require certain path information, __this notebook should be run with the tutorial folder as the root directory__.

# %% [markdown]
# All interpretation modules may be invoked in three ways:
#     1) From the command line: fastestimator visualize COMMAND
#     2) From a python API: visualize_COMMAND()
#     3) From a __Trace__ which may then be combined with the __TensorBoard__ __Trace__ or any other image IO __Trace__

# %% [markdown]
# ## Download a sample model for demonstration

# %%
import tensorflow as tf
import os

model = tf.keras.applications.InceptionV3(weights='imagenet')  # This will download a .h5 file to ~/.keras/models
os.makedirs('./outputs', exist_ok=True)
model.save('./outputs/inceptionV3.h5')

# %% [markdown]
# ## Interpretation with Bash
#
# We'll start by running the caricature interpretation via the command line. Depending on how you downloaded FastEstimator, you may need to run `python setup.py install` from the parent directory in order to invoke the fastestimator command. For the next few examples we'll be considering an image of a pirate ship: <div>&quot;<a href='https://www.flickr.com/photos/torley/3104607205/' target='_blank'>pirate ship by teepunch Jacobus</a>&quot;&nbsp;(<a rel='license' href='https://creativecommons.org/licenses/by-sa/2.0/' target='_blank'>CC BY-SA 2.0</a>)&nbsp;by&nbsp;<a xmlns:cc='http://creativecommons.org/ns#' rel='cc:attributionURL' property='cc:attributionName' href='https://www.flickr.com/people/torley/' target='_blank'>TORLEY</a></div>

# %%
# !fastestimator visualize caricature ./outputs/inceptionV3.h5 ./image/pirates.jpg --layers 196 --dictionary ./image/imagenet_class_index.json --save ./outputs
# Out:
# 2019-10-21 18:49:55.319022: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-10-21 18:49:55.326394: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300040000 Hz
# 2019-10-21 18:49:55.326640: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5579b2faad20 executing computations on platform Host. Devices:
# 2019-10-21 18:49:55.326672: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2019-10-21 18:49:55.329527: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-10-21 18:49:55.398864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.399310: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5579b30735b0 executing computations on platform CUDA. Devices:
# 2019-10-21 18:49:55.399343: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-10-21 18:49:55.399557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.399918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:1e.0
# 2019-10-21 18:49:55.400234: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-10-21 18:49:55.401786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2019-10-21 18:49:55.403103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2019-10-21 18:49:55.403452: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2019-10-21 18:49:55.405188: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2019-10-21 18:49:55.406487: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2019-10-21 18:49:55.410509: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-10-21 18:49:55.410656: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.411101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.411447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-10-21 18:49:55.411524: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-10-21 18:49:55.412933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-10-21 18:49:55.412981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-10-21 18:49:55.413003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-10-21 18:49:55.413165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.413541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.413872: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 220 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7)
# 2019-10-21 18:49:55.663649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.664031: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:1e.0
# 2019-10-21 18:49:55.664107: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-10-21 18:49:55.664141: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2019-10-21 18:49:55.664172: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2019-10-21 18:49:55.664202: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2019-10-21 18:49:55.664233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2019-10-21 18:49:55.664262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2019-10-21 18:49:55.664293: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-10-21 18:49:55.664374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.664767: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.665064: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-10-21 18:49:55.665515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.665826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:1e.0
# 2019-10-21 18:49:55.665871: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-10-21 18:49:55.665904: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2019-10-21 18:49:55.665934: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2019-10-21 18:49:55.665963: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2019-10-21 18:49:55.665992: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2019-10-21 18:49:55.666021: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2019-10-21 18:49:55.666051: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-10-21 18:49:55.666129: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.666506: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.666803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-10-21 18:49:55.666839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-10-21 18:49:55.666854: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-10-21 18:49:55.666866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-10-21 18:49:55.666975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.667333: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-10-21 18:49:55.667672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 220 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7)
# 2019-10-21 18:50:01.214159: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-10-21 18:50:02.010905: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 549.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.027562: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 208.66MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.037834: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.054746: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 305.05MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.056909: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2019-10-21 18:50:02.237435: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.93GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.240588: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 82.05MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.240651: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 211.75MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.249561: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 216.27MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.251766: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 42.88MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.251809: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 45.32MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-10-21 18:50:02.341511: W tensorflow/core/kernels/conv_ops.cc:1014] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2019-10-21 18:50:12.366733: W tensorflow/core/common_runtime/bfc_allocator.cc:419] Allocator (GPU_0_bfc) ran out of memory trying to allocate 216.8KiB (rounded to 221952).  Current allocation summary follows.
# 2019-10-21 18:50:12.366814: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (256): 	Total Chunks: 77, Chunks in use: 76. 19.2KiB allocated for chunks. 19.0KiB in use in bin. 16.8KiB client-requested in use in bin.
# 2019-10-21 18:50:12.366833: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (512): 	Total Chunks: 227, Chunks in use: 226. 155.0KiB allocated for chunks. 154.5KiB in use in bin. 143.8KiB client-requested in use in bin.
# 2019-10-21 18:50:12.366846: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (1024): 	Total Chunks: 76, Chunks in use: 73. 112.5KiB allocated for chunks. 108.0KiB in use in bin. 106.8KiB client-requested in use in bin.
# 2019-10-21 18:50:12.366856: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (2048): 	Total Chunks: 3, Chunks in use: 3. 8.0KiB allocated for chunks. 8.0KiB in use in bin. 6.1KiB client-requested in use in bin.
# 2019-10-21 18:50:12.366871: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (4096): 	Total Chunks: 2, Chunks in use: 1. 8.8KiB allocated for chunks. 4.0KiB in use in bin. 3.9KiB client-requested in use in bin.
# 2019-10-21 18:50:12.366893: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (8192): 	Total Chunks: 1, Chunks in use: 0. 13.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-10-21 18:50:12.366912: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-10-21 18:50:12.366931: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (32768): 	Total Chunks: 7, Chunks in use: 6. 306.5KiB allocated for chunks. 270.5KiB in use in bin. 212.0KiB client-requested in use in bin.
# 2019-10-21 18:50:12.366946: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (65536): 	Total Chunks: 14, Chunks in use: 13. 1.13MiB allocated for chunks. 1.06MiB in use in bin. 979.1KiB client-requested in use in bin.
# 2019-10-21 18:50:12.366957: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (131072): 	Total Chunks: 116, Chunks in use: 116. 21.99MiB allocated for chunks. 21.99MiB in use in bin. 21.91MiB client-requested in use in bin.
# 2019-10-21 18:50:12.366972: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (262144): 	Total Chunks: 77, Chunks in use: 77. 27.95MiB allocated for chunks. 27.95MiB in use in bin. 26.84MiB client-requested in use in bin.
# 2019-10-21 18:50:12.366988: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (524288): 	Total Chunks: 45, Chunks in use: 45. 34.70MiB allocated for chunks. 34.70MiB in use in bin. 31.99MiB client-requested in use in bin.
# 2019-10-21 18:50:12.367003: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (1048576): 	Total Chunks: 23, Chunks in use: 23. 33.94MiB allocated for chunks. 33.94MiB in use in bin. 30.32MiB client-requested in use in bin.
# 2019-10-21 18:50:12.367019: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (2097152): 	Total Chunks: 17, Chunks in use: 17. 48.46MiB allocated for chunks. 48.46MiB in use in bin. 42.41MiB client-requested in use in bin.
# 2019-10-21 18:50:12.367030: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (4194304): 	Total Chunks: 8, Chunks in use: 8. 41.95MiB allocated for chunks. 41.95MiB in use in bin. 37.65MiB client-requested in use in bin.
# 2019-10-21 18:50:12.367044: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 9.72MiB allocated for chunks. 9.72MiB in use in bin. 7.81MiB client-requested in use in bin.
# 2019-10-21 18:50:12.367054: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-10-21 18:50:12.367067: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-10-21 18:50:12.367076: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-10-21 18:50:12.367090: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-10-21 18:50:12.367098: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-10-21 18:50:12.367112: I tensorflow/core/common_runtime/bfc_allocator.cc:885] Bin for 216.8KiB was 128.0KiB, Chunk State:
# 2019-10-21 18:50:12.367125: I tensorflow/core/common_runtime/bfc_allocator.cc:898] Next region of size 231145472
# 2019-10-21 18:50:12.367141: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b60000 next 1 of size 1280
# 2019-10-21 18:50:12.367158: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b60500 next 2 of size 256
# 2019-10-21 18:50:12.367169: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b60600 next 5 of size 256
# 2019-10-21 18:50:12.367185: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b
I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b89e00 next 160 of size 512
# 2019-10-21 18:50:12.368478: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8a000 next 161 of size 512
# 2019-10-21 18:50:12.368489: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8a200 next 162 of size 512
# 2019-10-21 18:50:12.368505: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8a400 next 163 of size 512
# 2019-10-21 18:50:12.368517: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8a600 next 164 of size 512
# 2019-10-21 18:50:12.368533: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8a800 next 166 of size 512
# 2019-10-21 18:50:12.368544: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8aa00 next 168 of size 512
# 2019-10-21 18:50:12.368560: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8ac00 next 169 of size 512
# 2019-10-21 18:50:12.368571: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8ae00 next 171 of size 512
# 2019-10-21 18:50:12.368582: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8b000 next 173 of size 512
# 2019-10-21 18:50:12.368598: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8b200 next 174 of size 512
# 2019-10-21 18:50:12.368609: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8b400 next 175 of size 512
# 2019-10-21 18:50:12.368643: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8b600 next 177 of size 512
# 2019-10-21 18:50:12.368659: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8b800 next 180 of size 512
# 2019-10-21 18:50:12.368670: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8ba00 next 181 of size 512
# 2019-10-21 18:50:12.368681: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8bc00 next 182 of size 512
# 2019-10-21 18:50:12.368692: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8be00 next 183 of size 512
# 2019-10-21 18:50:12.368708: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8c000 next 184 of size 512
# 2019-10-21 18:50:12.368720: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8c200 next 185 of size 512
# 2019-10-21 18:50:12.368736: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8c400 next 186 of size 512
# 2019-10-21 18:50:12.368747: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8c600 next 189 of size 512
# 2019-10-21 18:50:12.368763: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8c800 next 190 of size 512
# 2019-10-21 18:50:12.368775: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8ca00 next 191 of size 512
# 2019-10-21 18:50:12.368791: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8cc00 next 192 of size 512
# 2019-10-21 18:50:12.368803: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8ce00 next 193 of size 512
# 2019-10-21 18:50:12.368819: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8d000 next 194 of size 512
# 2019-10-21 18:50:12.368830: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8d200 next 195 of size 512
# 2019-10-21 18:50:12.368846: I tensorflow/core/common_runtime/bfc_allocator.cc:905] Free  at 0x1203b8d400 next 196 of size 512
# 2019-10-21 18:50:12.368858: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8d600 next 199 of size 768
# 2019-10-21 18:50:12.368874: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8d900 next 202 of size 768
# 2019-10-21 18:50:12.368885: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8dc00 next 204 of size 768
# 2019-10-21 18:50:12.368901: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8df00 next 205 of size 768
# 2019-10-21 18:50:12.368913: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8e200 next 206 of size 768
# 2019-10-21 18:50:12.368924: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8e500 next 207 of size 768
# 2019-10-21 18:50:12.368934: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8e800 next 208 of size 768
# 2019-10-21 18:50:12.368950: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8eb00 next 209 of size 768
# 2019-10-21 18:50:12.368962: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8ee00 next 210 of size 768
# 2019-10-21 18:50:12.368978: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8f100 next 211 of size 768
# 2019-10-21 18:50:12.368990: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8f400 next 212 of size 768
# 2019-10-21 18:50:12.369005: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8f700 next 213 of size 768
# 2019-10-21 18:50:12.369017: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8fa00 next 214 of size 768
# 2019-10-21 18:50:12.369033: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b8fd00 next 17 of size 1280
# 2019-10-21 18:50:12.369045: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203b90200 next 15 of size 73728
# 2019-10-21 18:50:12.369061: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba2200 next 240 of size 1792
# 2019-10-21 18:50:12.369073: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba2900 next 91 of size 1536
# 2019-10-21 18:50:12.369089: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba2f00 next 420 of size 1536
# 2019-10-21 18:50:12.369100: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba3500 next 155 of size 1792
# 2019-10-21 18:50:12.369117: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba3c00 next 490 of size 4096
# 2019-10-21 18:50:12.369128: I tensorflow/core/common_runtime/bfc_allocator.cc:905] Free  at 0x1203ba4c00 next 53 of size 13824
# 2019-10-21 18:50:12.369145: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8200 next 55 of size 256
# 2019-10-21 18:50:12.369156: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8300 next 56 of size 256
# 2019-10-21 18:50:12.369166: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8400 next 57 of size 256
# 2019-10-21 18:50:12.369177: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8500 next 58 of size 256
# 2019-10-21 18:50:12.369193: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8600 next 59 of size 256
# 2019-10-21 18:50:12.369204: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8700 next 60 of size 256
# 2019-10-21 18:50:12.369220: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8800 next 61 of size 256
# 2019-10-21 18:50:12.369234: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8900 next 62 of size 256
# 2019-10-21 18:50:12.369250: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8a00 next 63 of size 512
# 2019-10-21 18:50:12.369261: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8c00 next 64 of size 512
# 2019-10-21 18:50:12.369277: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba8e00 next 65 of size 512
# 2019-10-21 18:50:12.369289: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9000 next 66 of size 512
# 2019-10-21 18:50:12.369304: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9200 next 67 of size 256
# 2019-10-21 18:50:12.369315: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9300 next 68 of size 256
# 2019-10-21 18:50:12.369326: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9400 next 69 of size 256
# 2019-10-21 18:50:12.369343: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9500 next 70 of size 256
# 2019-10-21 18:50:12.369354: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9600 next 71 of size 256
# 2019-10-21 18:50:12.369371: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9700 next 72 of size 256
# 2019-10-21 18:50:12.369383: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9800 next 73 of size 256
# 2019-10-21 18:50:12.369394: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9900 next 75 of size 256
# 2019-10-21 18:50:12.369404: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9a00 next 77 of size 256
# 2019-10-21 18:50:12.369415: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9b00 next 79 of size 256
# 2019-10-21 18:50:12.369426: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9c00 next 80 of size 256
# 2019-10-21 18:50:12.369437: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9d00 next 81 of size 256
# 2019-10-21 18:50:12.369452: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203ba9e00 next 82 of size 512
# 2019-10-21 18:50:12.369464: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baa000 next 83 of size 512
# 2019-10-21 18:50:12.369480: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baa200 next 84 of size 512
# 2019-10-21 18:50:12.369491: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baa400 next 85 of size 512
# 2019-10-21 18:50:12.369507: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baa600 next 88 of size 256
# 2019-10-21 18:50:12.369519: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baa700 next 92 of size 256
# 2019-10-21 18:50:12.369534: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baa800 next 93 of size 256
# 2019-10-21 18:50:12.369546: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baa900 next 94 of size 256
# 2019-10-21 18:50:12.369562: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baaa00 next 95 of size 256
# 2019-10-21 18:50:12.369573: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baab00 next 96 of size 256
# 2019-10-21 18:50:12.369589: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baac00 next 97 of size 256
# 2019-10-21 18:50:12.369600: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baad00 next 98 of size 256
# 2019-10-21 18:50:12.369616: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baae00 next 99 of size 512
# 2019-10-21 18:50:12.369628: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bab000 next 100 of size 512
# 2019-10-21 18:50:12.369643: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bab200 next 101 of size 512
# 2019-10-21 18:50:12.369655: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bab400 next 102 of size 512
# 2019-10-21 18:50:12.369666: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bab600 next 103 of size 256
# 2019-10-21 18:50:12.369676: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bab700 next 104 of size 256
# 2019-10-21 18:50:12.369692: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bab800 next 105 of size 256
# 2019-10-21 18:50:12.369704: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bab900 next 106 of size 256
# 2019-10-21 18:50:12.369715: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baba00 next 108 of size 256
# 2019-10-21 18:50:12.369730: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203babb00 next 110 of size 256
# 2019-10-21 18:50:12.369742: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203babc00 next 111 of size 256
# 2019-10-21 18:50:12.369758: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203babd00 next 112 of size 256
# 2019-10-21 18:50:12.369769: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203babe00 next 115 of size 256
# 2019-10-21 18:50:12.369785: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203babf00 next 116 of size 256
# 2019-10-21 18:50:12.369797: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bac000 next 117 of size 256
# 2019-10-21 18:50:12.369813: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bac100 next 118 of size 256
# 2019-10-21 18:50:12.369824: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bac200 next 119 of size 512
# 2019-10-21 18:50:12.369840: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bac400 next 120 of size 512
# 2019-10-21 18:50:12.369852: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bac600 next 121 of size 512
# 2019-10-21 18:50:12.369868: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bac800 next 122 of size 512
# 2019-10-21 18:50:12.369880: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203baca00 next 126 of size 256
# 2019-10-21 18:50:12.369895: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bacb00 next 127 of size 256
# 2019-10-21 18:50:12.369907: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bacc00 next 128 of size 256
# 2019-10-21 18:50:12.369923: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bacd00 next 129 of size 256
# 2019-10-21 18:50:12.369935: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bace00 next 130 of size 256
# 2019-10-21 18:50:12.369946: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bacf00 next 131 of size 256
# 2019-10-21 18:50:12.369962: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bad000 next 132 of size 256
# 2019-10-21 18:50:12.369974: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bad100 next 133 of size 256
# 2019-10-21 18:50:12.369989: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bad200 next 134 of size 512
# 2019-10-21 18:50:12.370001: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bad400 next 135 of size 512
# 2019-10-21 18:50:12.370011: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bad600 next 136 of size 512
# 2019-10-21 18:50:12.370027: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bad800 next 137 of size 512
# 2019-10-21 18:50:12.370038: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bada00 next 138 of size 256
# 2019-10-21 18:50:12.370054: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203badb00 next 139 of size 256
# 2019-10-21 18:50:12.370065: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203badc00 next 140 of size 256
# 2019-10-21 18:50:12.370081: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203badd00 next 141 of size 256
# 2019-10-21 18:50:12.370093: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bade00 next 143 of size 256
# 2019-10-21 18:50:12.370108: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203badf00 next 144 of size 256
# 2019-10-21 18:50:12.370120: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bae000 next 145 of size 256
# 2019-10-21 18:50:12.370136: I tensorflow/core/common_runtime/bfc_allocator.cc:905] Free  at 0x1203bae100 next 33 of size 256
# 2019-10-21 18:50:12.370148: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bae200 next 31 of size 49152
# 2019-10-21 18:50:12.370159: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bba200 next 113 of size 276480
# 2019-10-21 18:50:12.370169: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bfda00 next 481 of size 1280
# 2019-10-21 18:50:12.370185: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bfdf00 next 482 of size 1280
# 2019-10-21 18:50:12.370197: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bfe400 next 483 of size 1280
# 2019-10-21 18:50:12.370213: I tensorflow/core/common_runtime/bfc_allocator.cc:905] Free  at 0x1203bfe900 next 484 of size 1280
# 2019-10-21 18:50:12.370224: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bfee00 next 485 of size 768
# 2019-10-21 18:50:12.370240: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bff100 next 486 of size 768
# 2019-10-21 18:50:12.370252: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203bff400 next 487 of size 768
# 2019-10-21 18:50:12.370268: I tensorflow/core/common_runtime/bfc_allocator.cc:905] Free  at 0x1203bff700 next 489 of size 4864
# 2019-10-21 18:50:12.370280: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203c00a00 next 491 of size 3584
# 2019-10-21 18:50:12.370296: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1203c01800 next 89 of size 59904
# ...
# 2019-10-21 18:50:12.378310: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x12113b3e00 next 682 of size 221952
# 2019-10-21 18:50:12.378322: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x12113ea100 next 683 of size 221952
# 2019-10-21 18:50:12.378337: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1211420400 next 684 of size 221952
# 2019-10-21 18:50:12.378349: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x1211456700 next 685 of size 221952
# 2019-10-21 18:50:12.378365: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x121148ca00 next 686 of size 221952
# 2019-10-21 18:50:12.378377: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0
I tensorflow/core/common_runtime/bfc_allocator.cc:929] Stats:
# Limit:                   231145472
# InUse:                   231010816
# MaxInUse:                231010816
# NumAllocs:                    3351
# MaxAllocSize:             71747584
#
# 2019-10-21 18:50:12.379731: W tensorflow/core/common_runtime/bfc_allocator.cc:424] ****************************************************************************************************
# 2019-10-21 18:50:12.379777: W tensorflow/core/framework/op_kernel.cc:1622] OP_REQUIRES failed at conv_ops.cc:947 : Resource exhausted: OOM when allocating tensor with shape[1,192,17,17] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/nightly/bin/fastestimator", line 7, in <module>
#     exec(compile(f.read(), __file__, 'exec'))
#   File "/home/ubuntu/fastestimator/bin/fastestimator", line 35, in <module>
#     run()
#   File "/home/ubuntu/fastestimator/bin/fastestimator", line 31, in run
#     args.func(vars(args), unknown)
#   File "/home/ubuntu/fastestimator/fastestimator/cli/visualize.py", line 275, in caricature
#     sigmoid=not args['hard_clip'])
#   File "/home/ubuntu/fastestimator/fastestimator/cli/cli_util.py", line 160, in load_and_caricature
#     sigmoid=sigmoid)
#   File "/home/ubuntu/fastestimator/fastestimator/interpretation/caricature.py", line 252, in visualize_caricature
#     sigmoid=sigmoid)
#   File "/home/ubuntu/fastestimator/fastestimator/interpretation/caricature.py", line 169, in plot_caricature
#     predictions = np.asarray(model(model_input))
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py", line 891, in __call__
#     outputs = self.call(cast_inputs, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py", line 708, in call
#     convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py", line 860, in _run_internal_graph
#     output_tensors = layer(computed_tensors, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py", line 891, in __call__
#     outputs = self.call(cast_inputs, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/keras/layers/convolutional.py", line 197, in call
#     outputs = self._convolution_op(inputs, self.kernel)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py", line 1134, in __call__
#     return self.conv_op(inp, filter)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py", line 639, in __call__
#     return self.call(inp, filter)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py", line 238, in __call__
#     name=self.name)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py", line 2010, in conv2d
#     name=name)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_nn_ops.py", line 1031, in conv2d
#     data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_nn_ops.py", line 1130, in conv2d_eager_fallback
#     ctx=_ctx, name=name)
#   File "/home/ubuntu/anaconda3/envs/nightly/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py", line 67, in quick_execute
#     six.raise_from(core._status_to_exception(e.code, message), None)
#   File "<string>", line 3, in raise_from
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: OOM when allocating tensor with shape[1,192,17,17] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Conv2D]

# %% [markdown]
# Now lets load the image generated from the bash command back into memory for visualization:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from fastestimator.interpretation import show_image


caricature = plt.imread('./outputs/caricatures.png')
mpl.rcParams['figure.dpi']=300
show_image(caricature)
plt.show()

# %% [markdown]
# A human who was trying to identify a pirate ship would likely focus on 2 key components: whether they are looking at a ship, and whether that ship is flying a pirate flag. From the caricature we can see that the stern of the ship is strongly emphasized, and that there is a large but ambiguously structured area for the sails. Interestingly, the pirate flag is completely absent from the caricature -- perhaps indicating the network is not interested in the flag. Our next interpretation module will investigate this more closesly.

# %% [markdown]
# ## Interpretation with Python API
#
# Now lets run a saliency analysis (a different interpretation method), this time via the FastEstimator python API. We'll start by loading the pirate image into memory and sizing it appropriately

# %%
from fastestimator.util.util import load_dict, load_image

input_type = model.input.dtype
input_shape = model.input.shape
n_channels = 0 if len(input_shape) == 3 else input_shape[3]
input_height = input_shape[1]
input_width = input_shape[2]
inputs = [load_image('./image/pirates.jpg', channels=n_channels)]
tf_image = tf.stack([
    tf.image.resize_with_pad(tf.convert_to_tensor(im, dtype=input_type),
                             input_height,
                             input_width,
                             method='lanczos3') for im in inputs
])
pirates = tf.clip_by_value(tf_image, -1, 1)
dic = load_dict('./image/imagenet_class_index.json')
baseline = tf.zeros_like(pirates) + 0.5

# %% [markdown]
# Now lets run the FE saliency api:

# %%
from fastestimator.interpretation import visualize_saliency

visualize_saliency(model, pirates, baseline_input=baseline, decode_dictionary=dic, save_path=None)

# %% [markdown]
# Here we can see that, as in the caricature analysis, there seems to be strong emphasis on the stern of the ship, with some focus on the sails, but none on the pirate flag. It seems likely that the neural network has not learned that pirates are regular boats with a flag modifier, but rather that it has correlated a certain stereotypical ship design with pirate ships.

# %% [markdown]
# ## Interpretation with Traces
#
# We now move on to a discussion of interpretation with Traces. For this example we will switch to the CIFAR10 dataset and see how UMAPs can be used to visualize what a network 'knows' about different classes.

# %%
import tensorflow as tf
from tensorflow.python.keras import layers, Sequential, Model

from fastestimator import Pipeline, Network, build, Estimator
from fastestimator.op.tensorop import Minmax, ModelOp, SparseCategoricalCrossentropy
from tensorflow.python.keras import layers, Sequential
from fastestimator.trace import UMap, ConfusionMatrix

def LeNet_2Heads(input_shape=(28, 28, 1), classes=10):
    # A regular LeNet model, but with a second output head just before the softmax layer
    inp = layers.Input(shape=input_shape)
    x = layers.Conv2D(32, (3, 3), activation='relu')(inp)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation='relu')(x)
    final = layers.Dense(classes, activation='softmax')(x)
    model = Model(inputs=inp, outputs=[final, x])
    return model



(x_train, y_train), (x_eval, y_eval) = tf.keras.datasets.cifar10.load_data()
data = {"train": {"x": x_train, "y": y_train}, "eval": {"x": x_eval, "y": y_eval}}
num_classes = 10
class_dictionary = {
    0: "airplane", 1: "car", 2: "bird", 3: "cat", 4: "deer", 5: "dog", 6: "frog", 7: "horse", 8: "ship", 9: "truck"
}

pipeline = Pipeline(batch_size=32, data=data, ops=Minmax(inputs="x", outputs="x"))

model = build(model_def=lambda: LeNet_2Heads(input_shape=x_train.shape[1:], classes=num_classes),
                 model_name="LeNet",
                 optimizer="adam",
                 loss_name="loss")

network = Network(ops=[
    ModelOp(inputs="x", model=model, outputs=("y_pred", "presoft")),
    SparseCategoricalCrossentropy(y_true="y", y_pred="y_pred", outputs="loss")
])

traces = [
    UMap(in_vector_key="presoft", label_vector_key="y", label_dict=class_dictionary, output_name="presoft_umap"),
    ConfusionMatrix("y", "y_pred", num_classes)
]

estimator = Estimator(network=network, pipeline=pipeline, traces=traces, epochs=5, log_steps=750)

# %%
estimator.fit()

# %% [markdown]
# As the UMaps reveal, the network is learning to separate man-made objects from natural ones. It also becomes clear that classes like 'cars' and 'trucks' are more similar to one another than they are to 'airplaines'. This all lines up with human intuition, which can increase confidence that the model has learned a useful embedding. The UMAP also helps to identify classes which will likely prove problematic for the network. In this case, the 'bird' class seems to be spread all over the map and therefore is likely to be confused with other classes. This is born out by the confusion matrix, which shows that the network has only 496 correct classifications for birds (class 2) vs 600+ for most of the other classes.
#
# If you want the Trace to save its output into TensorBoard, simply add a Tensorboard Trace to the traces list like follows:

# %%
from fastestimator.trace import TensorBoard

traces = [
    UMap(in_vector_key="presoft", label_vector_key="y", label_dict=class_dictionary, output_name="presoft_umap"),
    TensorBoard(write_images="presoft_umap")
]
